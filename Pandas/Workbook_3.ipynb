# %% [markdown]
# ### Import libraries for EDA

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %% [markdown]
# ### PANDAS by Corey

# %%
people={'first':['Tony','Captain','Black','Doctor','John','John','El','Pablo'],
        'last':['Stark','America','Widow','Strange','Doe','Murphy','Chapo','Escobar'],
        'email':['tonystark@email.com','captainamerica@email.com','blackwidow@email.com','doctorstrange@email.com','johndoe@email.com','johnmurphy@email.com','elchapo@email.com','pabloescobar@email.com']}

# %%
pdf=pd.DataFrame(people)

# %%
pdf
# Out:
#      first     last                     email
# 0     Tony    Stark       tonystark@email.com
# 1  Captain  America  captainamerica@email.com
# 2    Black    Widow      blackwidow@email.com
# 3   Doctor  Strange   doctorstrange@email.com
# 4     John      Doe         johndoe@email.com
# 5     John   Murphy      johnmurphy@email.com
# 6       El    Chapo         elchapo@email.com
# 7    Pablo  Escobar    pabloescobar@email.com

# %%
pdf['email']
# Out:
# 0         tonystark@email.com
# 1    captainamerica@email.com
# 2        blackwidow@email.com
# 3     doctorstrange@email.com
# 4           johndoe@email.com
# 5        johnmurphy@email.com
# 6           elchapo@email.com
# 7      pabloescobar@email.com
# Name: email, dtype: object

# %%
pdf[['email','first','last']]
# Out:
#                       email    first     last
# 0       tonystark@email.com     Tony    Stark
# 1  captainamerica@email.com  Captain  America
# 2      blackwidow@email.com    Black    Widow
# 3   doctorstrange@email.com   Doctor  Strange
# 4         johndoe@email.com     John      Doe
# 5      johnmurphy@email.com     John   Murphy
# 6         elchapo@email.com       El    Chapo
# 7    pabloescobar@email.com    Pablo  Escobar

# %%
pdf.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
pdf.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
pdf.iloc[0:4,0:3]
# Out:
#      first     last                     email
# 0     Tony    Stark       tonystark@email.com
# 1  Captain  America  captainamerica@email.com
# 2    Black    Widow      blackwidow@email.com
# 3   Doctor  Strange   doctorstrange@email.com

# %%
pdf.iloc[[0,1,3,5,7],0:3]
# Out:
#      first     last                     email
# 0     Tony    Stark       tonystark@email.com
# 1  Captain  America  captainamerica@email.com
# 3   Doctor  Strange   doctorstrange@email.com
# 5     John   Murphy      johnmurphy@email.com
# 7    Pablo  Escobar    pabloescobar@email.com

# %%
pdf.loc[[0,1,2,4,7],['first','last']]
# Out:
#      first     last
# 0     Tony    Stark
# 1  Captain  America
# 2    Black    Widow
# 4     John      Doe
# 7    Pablo  Escobar

# %%
pdf.loc[2:6:2,'first':'email']
# Out:
#    first   last                 email
# 2  Black  Widow  blackwidow@email.com
# 4   John    Doe     johndoe@email.com
# 6     El  Chapo     elchapo@email.com

# %%
pdf['first'].value_counts()
# Out:
# John       2
# El         1
# Doctor     1
# Captain    1
# Tony       1
# Black      1
# Pablo      1
# Name: first, dtype: int64

# %%
pdf['last'].value_counts()
# Out:
# Doe        1
# Widow      1
# America    1
# Chapo      1
# Murphy     1
# Strange    1
# Escobar    1
# Stark      1
# Name: last, dtype: int64

# %%
cond=(pdf['last']=='Strange')

# %%
pdf.loc[cond,['email','first']]
# Out:
#                      email   first
# 3  doctorstrange@email.com  Doctor

# %%
pdf.set_index('email')
# Out:
#                             first     last
# email
# tonystark@email.com          Tony    Stark
# captainamerica@email.com  Captain  America
# blackwidow@email.com        Black    Widow
# doctorstrange@email.com    Doctor  Strange
# johndoe@email.com            John      Doe
# johnmurphy@email.com         John   Murphy
# elchapo@email.com              El    Chapo
# pabloescobar@email.com      Pablo  Escobar

# %%
pdf
# Out:
#      first     last                     email
# 0     Tony    Stark       tonystark@email.com
# 1  Captain  America  captainamerica@email.com
# 2    Black    Widow      blackwidow@email.com
# 3   Doctor  Strange   doctorstrange@email.com
# 4     John      Doe         johndoe@email.com
# 5     John   Murphy      johnmurphy@email.com
# 6       El    Chapo         elchapo@email.com
# 7    Pablo  Escobar    pabloescobar@email.com

# %%
pdf.set_index('email',inplace=True)

# %%
pdf
# Out:
#                             first     last
# email
# tonystark@email.com          Tony    Stark
# captainamerica@email.com  Captain  America
# blackwidow@email.com        Black    Widow
# doctorstrange@email.com    Doctor  Strange
# johndoe@email.com            John      Doe
# johnmurphy@email.com         John   Murphy
# elchapo@email.com              El    Chapo
# pabloescobar@email.com      Pablo  Escobar

# %%
pdf['first']
# Out:
# email
# tonystark@email.com            Tony
# captainamerica@email.com    Captain
# blackwidow@email.com          Black
# doctorstrange@email.com      Doctor
# johndoe@email.com              John
# johnmurphy@email.com           John
# elchapo@email.com                El
# pabloescobar@email.com        Pablo
# Name: first, dtype: object

# %%
pdf[['first','last']]
# Out:
#                             first     last
# email
# tonystark@email.com          Tony    Stark
# captainamerica@email.com  Captain  America
# blackwidow@email.com        Black    Widow
# doctorstrange@email.com    Doctor  Strange
# johndoe@email.com            John      Doe
# johnmurphy@email.com         John   Murphy
# elchapo@email.com              El    Chapo
# pabloescobar@email.com      Pablo  Escobar

# %%
pdf.loc['tonystark@email.com':'johndoe@email.com']
# Out:
#                             first     last
# email
# tonystark@email.com          Tony    Stark
# captainamerica@email.com  Captain  America
# blackwidow@email.com        Black    Widow
# doctorstrange@email.com    Doctor  Strange
# johndoe@email.com            John      Doe

# %%
pdf.reset_index(inplace=False)
# Out:
#                       email    first     last
# 0       tonystark@email.com     Tony    Stark
# 1  captainamerica@email.com  Captain  America
# 2      blackwidow@email.com    Black    Widow
# 3   doctorstrange@email.com   Doctor  Strange
# 4         johndoe@email.com     John      Doe
# 5      johnmurphy@email.com     John   Murphy
# 6         elchapo@email.com       El    Chapo
# 7    pabloescobar@email.com    Pablo  Escobar

# %%
pdf.reset_index(inplace=True)

# %%
pdf.sort_index(ascending=False)
# Out:
#                       email    first     last
# 7    pabloescobar@email.com    Pablo  Escobar
# 6         elchapo@email.com       El    Chapo
# 5      johnmurphy@email.com     John   Murphy
# 4         johndoe@email.com     John      Doe
# 3   doctorstrange@email.com   Doctor  Strange
# 2      blackwidow@email.com    Black    Widow
# 1  captainamerica@email.com  Captain  America
# 0       tonystark@email.com     Tony    Stark

# %%
pdf.describe()
# Out:
#                           email first last
# count                         8     8    8
# unique                        8     7    8
# top     doctorstrange@email.com  John  Doe
# freq                          1     2    1

# %%
pdf['first'].value_counts().to_frame()
# Out:
#          first
# John         2
# El           1
# Doctor       1
# Captain      1
# Tony         1
# Black        1
# Pablo        1

# %%
pdf.dtypes
# Out:
# email    object
# first    object
# last     object
# dtype: object

# %% [markdown]
# ......

# %%
c=(pdf['first']=='John')

# %%
pdf[c]
# Out:
#                   email first    last
# 4     johndoe@email.com  John     Doe
# 5  johnmurphy@email.com  John  Murphy

# %%
pdf.loc[c,['email','last']]
# Out:
#                   email    last
# 4     johndoe@email.com     Doe
# 5  johnmurphy@email.com  Murphy

# %%
c=(pdf['last']=='Doe')

# %%
pdf.loc[c,['first','email']]
# Out:
#   first              email
# 4  John  johndoe@email.com

# %%
d=(pdf['first']=='John') | (pdf['last']=='Doe')

# %%
pdf[d]
# Out:
#                   email first    last
# 4     johndoe@email.com  John     Doe
# 5  johnmurphy@email.com  John  Murphy

# %%
d=(pdf['first']=='John') & (pdf['last']=='Doe')

# %%
pdf[d]
# Out:
#                email first last
# 4  johndoe@email.com  John  Doe

# %%
d=(pdf['first']=='Tony') | (pdf['last']=='Widow') | (pdf['email']=='elchapo@email.com')

# %%
pdf[d]
# Out:
#                   email  first   last
# 0   tonystark@email.com   Tony  Stark
# 2  blackwidow@email.com  Black  Widow
# 6     elchapo@email.com     El  Chapo

# %%
pdf.loc[d,'email']
# Out:
# 0     tonystark@email.com
# 2    blackwidow@email.com
# 6       elchapo@email.com
# Name: email, dtype: object

# %%
pdf.loc[~d,['email','last']]
# Out:
#                       email     last
# 1  captainamerica@email.com  America
# 3   doctorstrange@email.com  Strange
# 4         johndoe@email.com      Doe
# 5      johnmurphy@email.com   Murphy
# 7    pabloescobar@email.com  Escobar

# %%
star=['Tony','Black','Pablo','John']

# %% [markdown]
# #### ISIN method

# %%
cond=pdf['first'].isin(star)

# %%
pdf.loc[cond]
# Out:
#                     email  first     last
# 0     tonystark@email.com   Tony    Stark
# 2    blackwidow@email.com  Black    Widow
# 4       johndoe@email.com   John      Doe
# 5    johnmurphy@email.com   John   Murphy
# 7  pabloescobar@email.com  Pablo  Escobar

# %% [markdown]
# X------X--------X

# %% [markdown]
# #### String Contains Method

# %%
cond=pdf['first'].str.contains('John')

# %%
pdf.loc[cond]
# Out:
#                   email first    last
# 4     johndoe@email.com  John     Doe
# 5  johnmurphy@email.com  John  Murphy

# %%
pdf.loc[~cond,['email','last']]
# Out:
#                       email     last
# 0       tonystark@email.com    Stark
# 1  captainamerica@email.com  America
# 2      blackwidow@email.com    Widow
# 3   doctorstrange@email.com  Strange
# 6         elchapo@email.com    Chapo
# 7    pabloescobar@email.com  Escobar

# %% [markdown]
# X------X-------X

# %% [markdown]
# ......

# %%
pdf.columns=['email_id','f_name','l_name']

# %%
pdf
# Out:
#                    email_id   f_name   l_name
# 0       tonystark@email.com     Tony    Stark
# 1  captainamerica@email.com  Captain  America
# 2      blackwidow@email.com    Black    Widow
# 3   doctorstrange@email.com   Doctor  Strange
# 4         johndoe@email.com     John      Doe
# 5      johnmurphy@email.com     John   Murphy
# 6         elchapo@email.com       El    Chapo
# 7    pabloescobar@email.com    Pablo  Escobar

# %%
pdf.columns=[x.upper() for x in pdf.columns]

# %%
pdf
# Out:
#                    EMAIL_ID   F_NAME   L_NAME
# 0       tonystark@email.com     Tony    Stark
# 1  captainamerica@email.com  Captain  America
# 2      blackwidow@email.com    Black    Widow
# 3   doctorstrange@email.com   Doctor  Strange
# 4         johndoe@email.com     John      Doe
# 5      johnmurphy@email.com     John   Murphy
# 6         elchapo@email.com       El    Chapo
# 7    pabloescobar@email.com    Pablo  Escobar

# %% [markdown]
# #####  String Replace

# %%
pdf.columns=pdf.columns.str.replace('_',' ')

# %%
pdf
# Out:
#                    EMAIL ID   F NAME   L NAME
# 0       tonystark@email.com     Tony    Stark
# 1  captainamerica@email.com  Captain  America
# 2      blackwidow@email.com    Black    Widow
# 3   doctorstrange@email.com   Doctor  Strange
# 4         johndoe@email.com     John      Doe
# 5      johnmurphy@email.com     John   Murphy
# 6         elchapo@email.com       El    Chapo
# 7    pabloescobar@email.com    Pablo  Escobar

# %% [markdown]
# X------X------X

# %%
pdf.rename(columns={'EMAIL ID':'Email Adress','F NAME':'First Name','L NAME':'Last Name'},inplace=True)

# %%
pdf.iloc[4]=['jurgenklopp@email.com','Jurgen','Klopp']

# %%
pdf.iloc[5,[0,2]]=['johndoe@email','Doe']

# %%
pdf.iloc[3,2]='Who'

# %%
pdf.iloc[3,0]='doctorwho@email.com'

# %%
pdf
# Out:
#                Email Adress First Name Last Name
# 0       tonystark@email.com       Tony     Stark
# 1  captainamerica@email.com    Captain   America
# 2      blackwidow@email.com      Black     Widow
# 3       doctorwho@email.com     Doctor       Who
# 4     jurgenklopp@email.com     Jurgen     Klopp
# 5             johndoe@email       John       Doe
# 6         elchapo@email.com         El     Chapo
# 7    pabloescobar@email.com      Pablo   Escobar

# %%
filt=(pdf['First Name']=='Captain')

# %%
pdf.loc[filt,'Email Address':'Last Name']=['brucewayne@email.com','Bruce','Wayne']

# %%
pdf
# Out:
#              Email Adress First Name Last Name
# 0     tonystark@email.com       Tony     Stark
# 1    brucewayne@email.com      Bruce     Wayne
# 2    blackwidow@email.com      Black     Widow
# 3     doctorwho@email.com     Doctor       Who
# 4   jurgenklopp@email.com     Jurgen     Klopp
# 5           johndoe@email       John       Doe
# 6       elchapo@email.com         El     Chapo
# 7  pabloescobar@email.com      Pablo   Escobar

# %%
pdf['Email Adress']=pdf['Email Adress'].str.upper()

# %%
pdf
# Out:
#              Email Adress First Name Last Name
# 0     TONYSTARK@EMAIL.COM       Tony     Stark
# 1    BRUCEWAYNE@EMAIL.COM      Bruce     Wayne
# 2    BLACKWIDOW@EMAIL.COM      Black     Widow
# 3     DOCTORWHO@EMAIL.COM     Doctor       Who
# 4   JURGENKLOPP@EMAIL.COM     Jurgen     Klopp
# 5           JOHNDOE@EMAIL       John       Doe
# 6       ELCHAPO@EMAIL.COM         El     Chapo
# 7  PABLOESCOBAR@EMAIL.COM      Pablo   Escobar

# %%
pdf['Last Name']=pdf['Last Name'].str.upper()

# %%
pdf
# Out:
#              Email Adress First Name Last Name
# 0     TONYSTARK@EMAIL.COM       Tony     STARK
# 1    BRUCEWAYNE@EMAIL.COM      Bruce     WAYNE
# 2    BLACKWIDOW@EMAIL.COM      Black     WIDOW
# 3     DOCTORWHO@EMAIL.COM     Doctor       WHO
# 4   JURGENKLOPP@EMAIL.COM     Jurgen     KLOPP
# 5           JOHNDOE@EMAIL       John       DOE
# 6       ELCHAPO@EMAIL.COM         El     CHAPO
# 7  PABLOESCOBAR@EMAIL.COM      Pablo   ESCOBAR

# %%
pdf['First Name']=pdf['First Name'].str.upper()

# %%
pdf
# Out:
#              Email Adress First Name Last Name
# 0     TONYSTARK@EMAIL.COM       TONY     STARK
# 1    BRUCEWAYNE@EMAIL.COM      BRUCE     WAYNE
# 2    BLACKWIDOW@EMAIL.COM      BLACK     WIDOW
# 3     DOCTORWHO@EMAIL.COM     DOCTOR       WHO
# 4   JURGENKLOPP@EMAIL.COM     JURGEN     KLOPP
# 5           JOHNDOE@EMAIL       JOHN       DOE
# 6       ELCHAPO@EMAIL.COM         EL     CHAPO
# 7  PABLOESCOBAR@EMAIL.COM      PABLO   ESCOBAR

# %%
pdf['Email Adress']=pdf['Email Adress'].str.lower()

# %%
pdf
# Out:
#              Email Adress First Name Last Name
# 0     tonystark@email.com       TONY     STARK
# 1    brucewayne@email.com      BRUCE     WAYNE
# 2    blackwidow@email.com      BLACK     WIDOW
# 3     doctorwho@email.com     DOCTOR       WHO
# 4   jurgenklopp@email.com     JURGEN     KLOPP
# 5           johndoe@email       JOHN       DOE
# 6       elchapo@email.com         EL     CHAPO
# 7  pabloescobar@email.com      PABLO   ESCOBAR

# %%
pdf.apply(len)
# Out:
# Email Adress    8
# First Name      8
# Last Name       8
# dtype: int64

# %%
pdf['Email Adress'].apply(len)
# Out:
# 0    19
# 1    20
# 2    20
# 3    19
# 4    21
# 5    13
# 6    17
# 7    22
# Name: Email Adress, dtype: int64

# %%
pdf.columns=pdf.columns.str.replace(' ','_')

# %%
pdf['First_Name']=pdf['First_Name'].apply(lambda x:x.lower())

# %%
pdf['Last_Name']=pdf['Last_Name'].apply(lambda x:x.lower())

# %%
pdf.applymap(len)
# Out:
#    Email_Adress  First_Name  Last_Name
# 0            19           4          5
# 1            20           5          5
# 2            20           5          5
# 3            19           6          3
# 4            21           6          5
# 5            13           4          3
# 6            17           2          5
# 7            22           5          7

# %%
pdf.applymap(str.lower)
# Out:
#              Email_Adress First_Name Last_Name
# 0     tonystark@email.com       tony     stark
# 1    brucewayne@email.com      bruce     wayne
# 2    blackwidow@email.com      black     widow
# 3     doctorwho@email.com     doctor       who
# 4   jurgenklopp@email.com     jurgen     klopp
# 5           johndoe@email       john       doe
# 6       elchapo@email.com         el     chapo
# 7  pabloescobar@email.com      pablo   escobar

# %%
pdf['First_Name'].map({'el':'clark','john':'steven'})
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5    steven
# 6     clark
# 7       NaN
# Name: First_Name, dtype: object

# %%
pdf['First_Name'].replace({'john':'clark','el':'cristiano','pablo':'lionel'},inplace=True)

# %%
pdf['Last_Name'].replace({'doe':'kent','chapo':'ronaldo','escobar':'messi'},inplace=True)

# %%
pdf
# Out:
#              Email_Adress First_Name Last_Name
# 0     tonystark@email.com       tony     stark
# 1    brucewayne@email.com      bruce     wayne
# 2    blackwidow@email.com      black     widow
# 3     doctorwho@email.com     doctor       who
# 4   jurgenklopp@email.com     jurgen     klopp
# 5           johndoe@email      clark      kent
# 6       elchapo@email.com  cristiano   ronaldo
# 7  pabloescobar@email.com     lionel     messi

# %% [markdown]
# ...

# %%
pdf['First_Name']+' '+pdf['Last_Name']
# Out:
# 0           tony stark
# 1          bruce wayne
# 2          black widow
# 3           doctor who
# 4         jurgen klopp
# 5           clark kent
# 6    cristiano ronaldo
# 7         lionel messi
# dtype: object

# %%
pdf['Full_Name']= pdf['First_Name']+' '+pdf['Last_Name']

# %%
pdf
# Out:
#              Email_Adress First_Name Last_Name          Full_Name
# 0     tonystark@email.com       tony     stark         tony stark
# 1    brucewayne@email.com      bruce     wayne        bruce wayne
# 2    blackwidow@email.com      black     widow        black widow
# 3     doctorwho@email.com     doctor       who         doctor who
# 4   jurgenklopp@email.com     jurgen     klopp       jurgen klopp
# 5           johndoe@email      clark      kent         clark kent
# 6       elchapo@email.com  cristiano   ronaldo  cristiano ronaldo
# 7  pabloescobar@email.com     lionel     messi       lionel messi

# %%
pdf.applymap(str.lower)
# Out:
#              Email_Adress First_Name Last_Name          Full_Name
# 0     tonystark@email.com       tony     stark         tony stark
# 1    brucewayne@email.com      bruce     wayne        bruce wayne
# 2    blackwidow@email.com      black     widow        black widow
# 3     doctorwho@email.com     doctor       who         doctor who
# 4   jurgenklopp@email.com     jurgen     klopp       jurgen klopp
# 5           johndoe@email      clark      kent         clark kent
# 6       elchapo@email.com  cristiano   ronaldo  cristiano ronaldo
# 7  pabloescobar@email.com     lionel     messi       lionel messi

# %%
pdf=pdf.applymap(str.capitalize)

# %%
pdf
# Out:
#              Email_Adress First_Name Last_Name          Full_Name
# 0     Tonystark@email.com       Tony     Stark         Tony stark
# 1    Brucewayne@email.com      Bruce     Wayne        Bruce wayne
# 2    Blackwidow@email.com      Black     Widow        Black widow
# 3     Doctorwho@email.com     Doctor       Who         Doctor who
# 4   Jurgenklopp@email.com     Jurgen     Klopp       Jurgen klopp
# 5           Johndoe@email      Clark      Kent         Clark kent
# 6       Elchapo@email.com  Cristiano   Ronaldo  Cristiano ronaldo
# 7  Pabloescobar@email.com     Lionel     Messi       Lionel messi

# %%
pdf.drop(columns=['First_Name','Last_Name'],inplace=True)

# %%
pdf
# Out:
#              Email_Adress          Full_Name
# 0     Tonystark@email.com         Tony stark
# 1    Brucewayne@email.com        Bruce wayne
# 2    Blackwidow@email.com        Black widow
# 3     Doctorwho@email.com         Doctor who
# 4   Jurgenklopp@email.com       Jurgen klopp
# 5           Johndoe@email         Clark kent
# 6       Elchapo@email.com  Cristiano ronaldo
# 7  Pabloescobar@email.com       Lionel messi

# %%
pdf['Full_Name'].str.split()
# Out:
# 0           [Tony, stark]
# 1          [Bruce, wayne]
# 2          [Black, widow]
# 3           [Doctor, who]
# 4         [Jurgen, klopp]
# 5           [Clark, kent]
# 6    [Cristiano, ronaldo]
# 7         [Lionel, messi]
# Name: Full_Name, dtype: object

# %%
pdf[['first','last']]=pdf['Full_Name'].str.split(' ',expand=True)

# %%
pdf['domain']=pdf['Email_Adress'].str.split('@',expand=True)

# %%
pdf.rename(columns={'domain':'username'},inplace=True)

# %%
pdf.columns=pdf.columns.str.replace('_','')

# %%
pdf
# Out:
#               emailadress           fullname      first     last      username
# 0     Tonystark@email.com         Tony stark       Tony    stark     Tonystark
# 1    Brucewayne@email.com        Bruce wayne      Bruce    wayne    Brucewayne
# 2    Blackwidow@email.com        Black widow      Black    widow    Blackwidow
# 3     Doctorwho@email.com         Doctor who     Doctor      who     Doctorwho
# 4   Jurgenklopp@email.com       Jurgen klopp     Jurgen    klopp   Jurgenklopp
# 5           Johndoe@email         Clark kent      Clark     kent       Johndoe
# 6       Elchapo@email.com  Cristiano ronaldo  Cristiano  ronaldo       Elchapo
# 7  Pabloescobar@email.com       Lionel messi     Lionel    messi  Pabloescobar

# %%
pdf.columns=pdf.columns.str.lower()

# %%
pdf
# Out:
#               emailadress           fullname      first     last      username
# 0     Tonystark@email.com         Tony stark       Tony    stark     Tonystark
# 1    Brucewayne@email.com        Bruce wayne      Bruce    wayne    Brucewayne
# 2    Blackwidow@email.com        Black widow      Black    widow    Blackwidow
# 3     Doctorwho@email.com         Doctor who     Doctor      who     Doctorwho
# 4   Jurgenklopp@email.com       Jurgen klopp     Jurgen    klopp   Jurgenklopp
# 5           Johndoe@email         Clark kent      Clark     kent       Johndoe
# 6       Elchapo@email.com  Cristiano ronaldo  Cristiano  ronaldo       Elchapo
# 7  Pabloescobar@email.com       Lionel messi     Lionel    messi  Pabloescobar

# %%
pdf=pdf.append({'emailadress':'billshankly@email.com','fullname':'Bill shankly','first':'bill','last':'shankly','username':'Billshankly'},ignore_index=True)

# %%
filt=(pdf['emailadress']=='billshankly@email.com')

# %%
pdf
# Out:
#               emailadress           fullname      first     last      username
# 0     Tonystark@email.com         Tony stark       Tony    stark     Tonystark
# 1    Brucewayne@email.com        Bruce wayne      Bruce    wayne    Brucewayne
# 2    Blackwidow@email.com        Black widow      Black    widow    Blackwidow
# 3     Doctorwho@email.com         Doctor who     Doctor      who     Doctorwho
# 4   Jurgenklopp@email.com       Jurgen klopp     Jurgen    klopp   Jurgenklopp
# 5           Johndoe@email         Clark kent      Clark     kent       Johndoe
# 6       Elchapo@email.com  Cristiano ronaldo  Cristiano  ronaldo       Elchapo
# 7  Pabloescobar@email.com       Lionel messi     Lionel    messi  Pabloescobar
# 8   billshankly@email.com       Bill shankly       bill  shankly   Billshankly

# %% [markdown]
# Till Part6 Here

# %%
df=pd.read_csv('IMDB-Movie-Data.csv')

# %%
df['Runtime (Minutes)']=(df['Runtime (Minutes)']/60)

# %%
df['Runtime (Minutes)']=df['Runtime (Minutes)'].round(3)

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...
